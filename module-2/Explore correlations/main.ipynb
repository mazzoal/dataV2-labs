# %% [markdown]
#  # Explore correlations

# %% [markdown]
# 1. Print the correlation matrix

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cdd = pd.read_csv("CDD.csv", sep="\t")
cdd
# Out:
#      EVENT CATEGORY EVENT GROUP                 EVENT SUBGROUP  \
# 0          Disaster     Natural  Meteorological - Hydrological
# 1          Disaster     Natural  Meteorological - Hydrological
# 2          Disaster     Natural  Meteorological - Hydrological
# 3          Disaster     Natural                     Biological
# 4          Incident  Technology            Hazardous Chemicals
# ...             ...         ...                            ...
# 1084       Disaster     Natural  Meteorological - Hydrological
# 1085       Incident  Technology                      Explosion
# 1086       Incident  Technology                      Explosion
# 1087       Incident  Technology         Infrastructure failure
# 1088       Incident  Technology                           Fire
#
#                        EVENT TYPE                                 PLACE  \
# 0     Storm - Unspecified / Other                   Christmas Island NS
# ...

# %%
null_cols = cdd.isnull().sum()
null_cols[null_cols > 0]
# Out:
# FATALITIES                          89
# INJURED / INFECTED                 115
# EVACUATED                           70
# ESTIMATED TOTAL COST               531
# NORMALIZED TOTAL COST              531
# FEDERAL DFAA PAYMENTS              604
# PROVINCIAL DFAA PAYMENTS           678
# PROVINCIAL DEPARTMENT PAYMENTS     997
# MUNICIPAL COSTS                   1060
# OGD COSTS                         1075
# INSURANCE PAYMENTS                1017
# NGO PAYMENTS                      1081
# UTILITY - PEOPLE AFFECTED           83
# MAGNITUDE                          114
# dtype: int64

# %%
cdd.corr()
# Out:
#                                 FATALITIES  INJURED / INFECTED  EVACUATED  \
# FATALITIES                        1.000000            0.998728  -0.003530
# INJURED / INFECTED                0.998728            1.000000  -0.003554
# EVACUATED                        -0.003530           -0.003554   1.000000
# ESTIMATED TOTAL COST              0.027839            0.073538   0.660335
# NORMALIZED TOTAL COST             0.031352            0.080907   0.580352
# FEDERAL DFAA PAYMENTS             0.014838            0.311491   0.406679
# PROVINCIAL DFAA PAYMENTS         -0.020317            0.404215   0.083692
# PROVINCIAL DEPARTMENT PAYMENTS   -0.023630           -0.002056   0.212975
# MUNICIPAL COSTS                   0.965880            0.965286   0.514186
# OGD COSTS                         0.417442           -0.036915   0.154761
# INSURANCE PAYMENTS                0.241347            0.456924   0.825937
# NGO PAYMENTS                      0.966678            0.999639   0.838898
# ...

# %% [markdown]
# 2. Print a heat map of this correlation matrix (hint: use seaborn.heatmap())

# %%
plt.figure(figsize=(15,15))

sns.heatmap(cdd.corr(), annot=True)

# %% [markdown]
# 3. Find 3 pairs of columns, one pair that is highly positively correlated, one for which the correlation is almost zero and one pair that is negatively correlated. In each case write down an explanation why we see this correlation

# %%
#example with high correlation

cdd['INSURANCE PAYMENTS'].corr(cdd['ESTIMATED TOTAL COST'])
# Out:
# 0.9239896007759513

# %%
#example with almost 0 correlation

cdd['ESTIMATED TOTAL COST'].corr(cdd['FATALITIES'])
# Out:
# 0.02783912627076404

# %%
#example with negative correlation

cdd['UTILITY - PEOPLE AFFECTED'].corr(cdd['OGD COSTS'])
# Out:
# -0.09298259907022133

# %% [markdown]
# 4. Look up the pairplot function in Seaborn. Use it to plot the pairwise relations between the six columns you selected. Does what you see confirm your ideas? Describe in a comment.

# %%
cdd1 = cdd[['INSURANCE PAYMENTS', 'ESTIMATED TOTAL COST']]

plot1 = sns.pairplot(cdd1)
plot1

# we can see that their is a positive corrolation in this graph, as the estimated total cost goes up, so does the insurance payment

# %%
cdd2 = cdd[['ESTIMATED TOTAL COST', 'FATALITIES']]

plot2 = sns.pairplot(cdd2)
plot2

# there is not clear correlation in this case, it can be seen from the lower left graph where the point seems to go into two direction without meaning

# %%
cdd3 = cdd[['UTILITY - PEOPLE AFFECTED', 'OGD COSTS']]

plot3 = sns.pairplot(cdd3)
plot3

#this show a really small negative correlation which is almost zero, it probably come fro this point that is slitly more on the right in the graph bell
