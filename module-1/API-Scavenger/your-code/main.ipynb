# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here
import json
import requests
import pandas as pd

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
# your code here
import requests
import pandas as pd

username = 'mazzoal'
token = ''

response = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/forks?page=1', auth=(username,token))
data = pd.DataFrame(response.json())

from pandas.io.json import json_normalize

results = response.json()
flattened_data = json_normalize(results)

flattened_data
# Out:
#            id                           node_id          name  \
# 0   242350251  MDEwOlJlcG9zaXRvcnkyNDIzNTAyNTE=   dataV2-labs
# 1   241335460  MDEwOlJlcG9zaXRvcnkyNDEzMzU0NjA=   dataV2-labs
# 2   241335029  MDEwOlJlcG9zaXRvcnkyNDEzMzUwMjk=   dataV2-labs
# 3   241334117  MDEwOlJlcG9zaXRvcnkyNDEzMzQxMTc=   dataV2-labs
# 4   241333755  MDEwOlJlcG9zaXRvcnkyNDEzMzM3NTU=   dataV2-labs
# 5   241332555  MDEwOlJlcG9zaXRvcnkyNDEzMzI1NTU=   dataV2-labs
# 6   241331710  MDEwOlJlcG9zaXRvcnkyNDEzMzE3MTA=   dataV2-labs
# 7   241331561  MDEwOlJlcG9zaXRvcnkyNDEzMzE1NjE=   dataV2-labs
# 8   241331355  MDEwOlJlcG9zaXRvcnkyNDEzMzEzNTU=   dataV2-labs
# 9   241331020  MDEwOlJlcG9zaXRvcnkyNDEzMzEwMjA=   dataV2-labs
# 10  240956256  MDEwOlJlcG9zaXRvcnkyNDA5NTYyNTY=   dataV2-labs
# 11  240120171  MDEwOlJlcG9zaXRvcnkyNDAxMjAxNzE=   dataV2-labs
# 12  240118951  MDEwOlJlcG9zaXRvcnkyNDAxMTg5NTE=   dataV2-labs
# 13  240117232  MDEwOlJlcG9zaXRvcnkyNDAxMTcyMzI=   dataV2-labs
# ...

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
url_adre = list(flattened_data["languages_url"])
print(url_adre)
# Out:
# ['https://api.github.com/repos/ta-data-lis/dataV2-labs/languages', 'https://api.github.com/repos/pmoreira1/dataV2-labs/languages', 'https://api.github.com/repos/mazzoal/dataV2-labs/languages', 'https://api.github.com/repos/c-cle/dataV2-labs/languages', 'https://api.github.com/repos/ReneRaube/dataV2-labs/languages', 'https://api.github.com/repos/PatrickColijn/dataV2-labs/languages', 'https://api.github.com/repos/Katja-Galyuk/dataV2-labs/languages', 'https://api.github.com/repos/PMoquette/dataV2-labs/languages', 'https://api.github.com/repos/diogoacabado/dataV2-labs/languages', 'https://api.github.com/repos/MafaldaFragoso/dataV2-labs/languages', 'https://api.github.com/repos/llopisaleix/dataV2-labs/languages', 'https://api.github.com/repos/AlvaroGSP/dataV2-labs/languages', 'https://api.github.com/repos/raphaeleon13/dataV2-labs/languages', 'https://api.github.com/repos/Gotharchitect/dataV2-labs/languages', 'https://api.github.com/repos/telmabatista/dataV2-labs/languages', 'https://api.g
# ...

# %%
flattened_data.columns
url_adre = list(flattened_data["languages_url"])

language_list= []

for i in url_adre:
    x=requests.get(i,auth=(username,token)).json()
    language_list.append(x)
    
print(language_list)
# Out:
# [{'Jupyter Notebook': 2464663, 'HTML': 498316, 'Python': 9907}, {'Jupyter Notebook': 3172054, 'HTML': 498316, 'TSQL': 6759, 'Python': 4720}, {'Jupyter Notebook': 3372491, 'HTML': 498316, 'Rich Text Format': 13142, 'Python': 9907}, {'Jupyter Notebook': 5579483, 'HTML': 498316, 'Python': 9907, 'TSQL': 3453}, {'Jupyter Notebook': 3823611, 'HTML': 498316, 'Python': 9907, 'Rich Text Format': 3552}, {'Jupyter Notebook': 2962744, 'HTML': 498316, 'Python': 9907}, {'Jupyter Notebook': 3484833, 'HTML': 498316, 'Python': 9907}, {'Jupyter Notebook': 3799889, 'HTML': 498316, 'Python': 11169, 'TSQL': 1578}, {'Jupyter Notebook': 5296493, 'HTML': 498316, 'TSQL': 122435, 'Python': 9907}, {'Jupyter Notebook': 4305287, 'HTML': 498316, 'Python': 9907, 'TSQL': 294}, {'Jupyter Notebook': 2464662, 'HTML': 498316, 'Python': 9907}, {'Jupyter Notebook': 2464662, 'HTML': 498316, 'Python': 9907}, {'Jupyter Notebook': 2464662, 'HTML': 498316, 'Python': 9907}, {'Jupyter Notebook': 2464662, 'HTML': 498316, 'Python
# ...

# %%
flattened_data.columns
url_adre = list(flattened_data["languages_url"])

language_list= []

for i in url_adre:
    x=requests.get(i,auth=(username,token)).json()
    language_list.append(x)
    
uni =[] 

for x in language_list:
    for k in x:
        uni.append(k)
        
unique_lang = set(uni)

print(unique_lang)

#for repos in flattened_data["language"]:
    #print(repos)
# Out:
# {'Rich Text Format', 'TSQL', 'Jupyter Notebook', 'Python', 'HTML'}

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here
import requests
import pandas as pd

username = 'mazzoal'
token = 'a8847f3f4234ed9537f069e69fc837fcda5babd8'

response = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/commits?since=2019-10-01T00:00:00Z&until=2019-10-31T23:59:59Z?page=1', auth=(username,token))
data = pd.DataFrame(response.json())

from pandas.io.json import json_normalize

results = response.json()
flattened_data1 = json_normalize(results)

flattened_data1


#flattened_data1["commit.author.date"]
# Out:
#                                          sha  \
# 0   37e0b0681ff829d1c9f4a542631229efe7d577ff
# 1   d9da31ef64900ad297d5d811d4f9c45e66fa8e8f
# 2   957cd5b2250076833fce0f363b42b4a77660e4eb
# 3   48503eb5aff61da2e7c1fdd55f3f7e407360ad29
# 4   a0cc914495a7e137e298cd6f5d47948b5cf64807
# 5   736bb6168cf59f0bfdc571e69db7986f7e5d54cb
# 6   b486d8528d53b940fb463850d6f841fa246607ef
# 7   974a906cc69c937b98f14a6c41f21a8fcb052082
# 8   e72aefda9202d5c9d06e3781d12dc8d79391857e
# 9   a3973031929ef5b1d8e30a2ff65c871423dae961
# 10  1184709677c2ffa1a674529c2c77fcdd3ebc647a
# 11  166c02fbaf7dd2908454f06e5cbbcddbcfb46361
# 12  eb96641d7cfafd678f4a306e7dff98d7448c11a5
# 13  44714932eed6b619ba67eb38448c5e9181334507
# 14  0bbbbc921961e66b5318d30a58482b8b79dc2612
# 15  085b537e4811cd2bcb8ebaa190e8370105a4471d
# 16  a4051c17c0c732501995754b2b75059ea32d09a6
# 17  af11edb6dfdc656d78a7053012388db1931cfba1
# 18  4f2ec891b69b3842dd2c20ca1665ddb8b10eb184
# 19  17356fa9ea0fda77dc9a1fb26c3dc2b2619c6aee
# ...

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
# your code here
len(flattened_data1)
# Out:
# 30

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
# your code here

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
